# %%
my_tup = (1, 2, 3)
print(type(my_tup))
print(my_tup[2])
# Out:
# <class 'tuple'>
# 3

# %%
tup = 1, 2, 3
a, b, c = tup
print(a * b * c)
# Out:
# 6

# %%
my_dictionary = {"A": 1, "B": 2} 
copy_my_dictionary = my_dictionary.copy() 
my_dictionary.clear() 
print(my_dictionary)
print(copy_my_dictionary)
# Out:
# {}
# {'A': 1, 'B': 2}

# %%
colors = {
    "white": (255, 255, 255),
    "grey": (128, 128, 128),
    "red": (255, 0, 0),
    "green": (0, 128, 0)
}

colors.items()
# Out:
# dict_items([('white', (255, 255, 255)), ('grey', (128, 128, 128)), ('red', (255, 0, 0)), ('green', (0, 128, 0))])

# %%
for col, rgb in colors.items():
    print(col, ":", rgb)
# Out:
# white : (255, 255, 255)
# grey : (128, 128, 128)
# red : (255, 0, 0)
# green : (0, 128, 0)

# %%
dict = {"a" : "b", 2 : [1,2,3]}
dict.keys()
# Out:
# dict_keys(['a', 2])

# %%
try: 
    value = int(input("Enter a value: ")) 
    print(value/value) 
except ValueError: 
    print("Bad input...") 
except ZeroDivisionError: 
    print("Very bad input...") 
except: 
    print("Booo!")

# %%
#DEBUG

# %%
pip help
# Out:
# Usage:
#   c:\Users\jozsef.szendrei\AppData\Local\Programs\Python\Python311\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
# ...

# %%
#pip freeze
# Out:
#   Cell In[18], line 2
#     pip list
#         ^
# SyntaxError: invalid syntax

# %%
pip list
# Out:
# Package               Version
# --------------------- --------
# asttokens             2.2.1
# attrs                 22.2.0
# backcall              0.2.0
# colorama              0.4.6
# comm                  0.1.2
# contourpy             1.0.7
# convertdate           2.4.0
# cycler                0.11.0
# Cython                0.29.33
# debugpy               1.6.5
# decorator             5.1.1
# entrypoints           0.4
# ephem                 4.1.4
# et-xmlfile            1.1.0
# executing             1.2.0
# fastjsonschema        2.16.2
# fonttools             4.38.0
# hijri-converter       2.2.4
# holidays              0.18
# ipykernel             6.19.4
# ipython               8.8.0
# jedi                  0.18.2
# joblib                1.2.0
# jsonschema            4.17.3
# jupyter_client        7.4.8
# jupyter_core          5.1.2
# kiwisolver            1.4.4
# korean-lunar-calendar 0.3.1
# LunarCalendar         0.0.9
# matplotlib            3.6.3
# ...

# %% [markdown]
# # https://pypi.org/

# %%
pip help install
# Out:
# Usage:
#   c:\Users\jozsef.szendrei\AppData\Local\Programs\Python\Python311\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   c:\Users\jozsef.szendrei\AppData\Local\Programs\Python\Python311\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   c:\Users\jozsef.szendrei\AppData\Local\Programs\Python\Python311\python.exe -m pip install [options] [-e] <vcs project url> ...
#   c:\Users\jozsef.szendrei\AppData\Local\Programs\Python\Python311\python.exe -m pip install [options] [-e] <local project path> ...
#   c:\Users\jozsef.szendrei\AppData\Local\Programs\Python\Python311\python.exe -m pip install [options] <archive url/path> ...
#
# Description:
#   Install packages from:
#
#   - PyPI (and other indexes) using requirement specifiers.
#   - VCS project urls.
#   - Local project directories.
#   - Local or remote source archives.
#
#   pip also supports installing from "requirements files", which provide
# ...

# %%
# pip install seaborn

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
display(iris.head(5))
sns.pairplot (iris, hue = 'species', palette = 'pastel')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# pip uninstall seaborn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import holidays
# Select country
hu_holidays = holidays.HU(years = 2018)
  
for ptr in hu_holidays.items():
    print(ptr)
# Out:
# (datetime.date(2018, 1, 1), 'Újév')
# (datetime.date(2018, 3, 15), 'Nemzeti ünnep')
# (datetime.date(2018, 3, 16), 'Nemzeti ünnep utáni pihenőnap')
# (datetime.date(2018, 3, 30), 'Nagypéntek')
# (datetime.date(2018, 4, 1), 'Húsvét')
# (datetime.date(2018, 4, 2), 'Húsvét Hétfő')
# (datetime.date(2018, 5, 20), 'Pünkösd')
# (datetime.date(2018, 5, 21), 'Pünkösdhétfő')
# (datetime.date(2018, 5, 1), 'A Munka ünnepe')
# (datetime.date(2018, 4, 30), 'A Munka ünnepe előtti pihenőnap')
# (datetime.date(2018, 8, 20), 'Az államalapítás ünnepe')
# (datetime.date(2018, 10, 23), 'Nemzeti ünnep')
# (datetime.date(2018, 10, 22), 'Nemzeti ünnep előtti pihenőnap')
# (datetime.date(2018, 11, 1), 'Mindenszentek')
# (datetime.date(2018, 11, 2), 'Mindenszentek utáni pihenőnap')
# (datetime.date(2018, 12, 24), 'Szenteste')
# (datetime.date(2018, 12, 25), 'Karácsony')
# (datetime.date(2018, 12, 26), 'Karácsony másnapja')
# (datetime.date(2018, 12, 31), 'Szilveszter')

# %%
# importing the required module 
import matplotlib.pyplot as plt
    
# x axis values 
x = [1,2,3] 
# corresponding y axis values 
y = [2,4,1] 
    
# plotting the points  
plt.plot(x, y) 
    
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
    
# giving a title to my graph 
plt.title('My first graph!') 
    
# function to show the plot 
plt.show()

# %%
# Python 3 fully supports Unicode and UTF-8:

# 1. you can use Unicode/UTF-8 encoded characters to name variables and other entities;

# 2. you can use them during all input and output.

# This means that Python3 is completely I18Ned.

# %% [markdown]
# A nemzetköziesítés (vagy rövidítve i18N) a szofverek több különböző nyelv kezelésére, megjelenítésére, illetve az azokon történő kommunikációra, tágabb értelemben pedig a világ különböző régióiban a helyi sajátosságok kezelésére történő felkészítése, illetve az ilyen, eltérő nyelvi és/vagy helyi változatok elkészítése (amit lokalizációnak is szokás hívni).

# %%
word = 'by'
print(len(word))
# Out:
# 2

# %%
empty = ''
print(len(empty))
# Out:
# 0

# %%
i_am = 'I\'m'
print(i_am)
print(len(i_am))
# Out:
# I'm
# 3

# %%
multiline = '''Line #1    
Line #2
asdasdasd
asdassdadas
asdasdasdassd
asdasdas'''
print(multiline)
print()
print(len(multiline))
# Out:
# Line #1
# Line #2
# asdasdasd
# asdassdadas
# asdasdasdassd
# asdasdas
#
# 64

# %%
str1 = 'a'
str2 = 'b'
print(str1 + str2)
print(str2 + str1)
print(5 * 'a')
print('b' * 4)
# Out:
# ab
# ba
# aaaaa
# bbbb

# %%
# Demonstrating the ord() function.
char_1 = 'a'
char_2 = ' ' # space
print(ord(char_1))
print(ord(char_2))
# Out:
# 97
# 32

# %%
# Demonstrating the chr() function.
print(chr(97))
print(chr(300))
# Out:
# a
# Ĭ

# %%
# Indexing strings.
the_string = 'silly walks'
for ix in range(len(the_string)):
    print(the_string[ix], end=' ')
print()
# Out:
# s i l l y   w a l k s

# %%
# Slices
alpha = "abdefg"
print(alpha[1:3])
print(alpha[3:])
print(alpha[:3])
print(alpha[3:-2])
print(alpha[-3:4])
print(alpha[::2])
print(alpha[1::2])
# Out:
# bd
# efg
# abd
# e
# e
# adf
# beg

# %%
# Iterating through a string.
the_string = 'silly walks'
for character in the_string:
    print(character, end=' ')
print()
# Out:
# s i l l y   w a l k s

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
print("f" in alphabet)
print("F" in alphabet)
print("1" in alphabet)
print("ghi" in alphabet)
print("Xyz" in alphabet)
# Out:
# True
# False
# False
# True
# False

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
del alphabet[0]
alphabet.append("A")
alphabet.insert(0, "A")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 alphabet = "abcdefghijklmnopqrstuvwxyz"
# ----> 2 del alphabet[0]
#       3 alphabet.append("A")
#       4 alphabet.insert(0, "A")
#
# TypeError: 'str' object doesn't support item deletion

# %%
# Demonstrating min() - Example 1:
print(min("aAbByYzZ"))
print(ord("z"),ord("a"))
# Demonstrating min() - Examples 2 & 3:
t = 'The Knights Who Say "Ni!"'
print('[' + min(t) + ']')
t = [0, 1, 2]
print(type(t))
print(min(t))
# Out:
# A
# 122 97
# [ ]
# <class 'list'>
# 0

# %%
# Demonstrating max() - Example 1:
print(max("aAbByYzZ"))
# Demonstrating max() - Examples 2 & 3:
t = 'The Knights Who Sayz "Ni!"'
print('[' + max(t) + ']')
t = [0, 1, 2]
print(max(t))
# Out:
# z
# [z]
# 2

# %%
# Demonstrating the list() function:
print(list("abcabc"))
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c']

# %%
# Demonstrating the index() method:
print("aAbByYzZaA".index("b"))
print("aAbByYzZaA".index("Z"))
print("aAbByYzZaA".index("A"))
# Out:
# 2
# 7
# 1

# %%
# Demonstrating the count() method:
print("abcabc".count("b"))
print('abcabc'.count("d"))
# Out:
# 2
# 0

# %%
# Demonstrating the capitalize() method:
print('aBcD'.capitalize())
# Out:
# Abcd

# %%
# Demonstrating the center() method:
print('[' + 'alpha'.center(11) + ']')
# Out:
# [   alpha   ]

# %%
# Demonstrating the endswith() method:
if "epsilonn".endswith("on"):
    print("yes")
else:
    print("no")
# Out:
# no

# %%
# Demonstrating the find() method:
print("Eta".find("ta"))
print("Eta".find("mmaaa"))
print('kappa'.find('a', 2))
# Out:
# 1
# -1
# 4

# %%
the_text = """A variation of the ordinary lorem ipsum
text has been used in typesetting since the 1960s 
or earlier, when it was popularized by advertisements 
for Letraset transfer sheets. It was introduced to 
the Information Age in the mid-1980s by the Aldus Corporation, 
which employed it in graphics and word-processing templates
for its desktop publishing program PageMaker (from Wikipedia)"""
fnd = the_text.find('of')
while fnd != -1:
    print(fnd)
    fnd = the_text.find('the', fnd + 1)
# Out:
# 12
# 15
# 80
# 198
# 221
# 238

# %%
# Demonstrating the isalnum() method:
print('lambda30'.isalnum())
print('lambda'.isalnum())
print('30'.isalnum())
print('@'.isalnum())
print('lambda_30'.isalnum())
print(''.isalnum())
# Out:
# True
# True
# True
# False
# False
# False

# %%
# Example 1: Demonstrating the isalpha() method:
print("Moooo".isalpha())
print('Mu40'.isalpha())
# Example 2: Demonstrating the isdigit() method:
print('2018'.isdigit())
print("Year2019".isdigit())
# Out:
# True
# False
# True
# False

# %%
# Example 1: Demonstrating the islower() method:
print("Moooo".islower())
print('moooo'.islower())
# Example 2: Demonstrating the isspace() method:
print(' \n '.isspace())
print(" ".isspace())
print("mooo mooo mooo".isspace())
# Example 3: Demonstrating the isupper() method:
print("Moooo".isupper())
print('moooo'.isupper())
print('MOOOO'.isupper())
# Out:
# False
# True
# True
# True
# False
# False
# False
# True

# %%
# Demonstrating the join() method:
print(".".join(["omicron", "pi", "rho"]))
# Out:
# omicron.pi.rho

# %%
# Demonstrating the lower() method:
print("SiGmA=60".lower())
# Out:
# sigma=60

# %%
# Demonstrating the lstrip() method:
print("[" + " \t tau ".lstrip() + "]")
# Out:
# [tau ]

# %%
# Demonstrating the replace() method:
print("www.netacad.com".replace("netacad.com", "pythoninstitute.org"))
print("This is it!".replace("is", "are"))
print("Apple juice".replace("juice", ""))
# Out:
# www.pythoninstitute.org
# Thare are it!
# Apple

# %%
# Demonstrating the rfind() method:
a = "tau tau tau"
print("tau tau tau".rfind("ta"))
print("tau tau tau".rfind("ta", 9))
print("tau tau tau".rfind("ta", 3, 9))
a[9]
# Out:
# 8
# -1
# 4
# 'a'

# %%
# Demonstrating the rstrip() method:
print("[" + " upsilon ".rstrip() + "]")
print("cisco.com".rstrip(".com"))
# Out:
# [ upsilon]
# cis

# %%
# Demonstrating the split() method:
print("phi chi\npsi".split())
# Out:
# ['phi', 'chi', 'psi']

# %%
# Demonstrating the startswith() method:
print("omega".startswith("meg"))
print("omega".startswith("om"))
print()
# Demonstrating the strip() method:
print("[" + " \t aleph ".strip() + "]")
# Out:
# False
# True
#
# [aleph]

# %%
# Demonstrating the swapcase() method:
print("I know that I know nothing.".swapcase())
print()
# Demonstrating the title() method:
print("I know that I know nothing. Part 1.".title())
print()
# Demonstrating the upper() method:
print("I know that I know nothing. Part 2.".upper())
# Out:
# i KNOW THAT i KNOW NOTHING.
#
# I Know That I Know Nothing. Part 1.
#
# I KNOW THAT I KNOW NOTHING. PART 2.

# %%
print('alpha' == 'alpha')
print('alpha' != 'Alpha')
print('alpha' < 'alphabet')
print('beta' > 'Beta')
print()
# Out:
# True
# True
# True
# True

# %%
print('10' == '010')
print('10' > '010')
print('10' > '8')
print('20' < '8')
print('20' < '80')
# Out:
# False
# True
# False
# True
# True

# %%
print('10' == 10)
print('10' != 10)
print('10' == 1)
print('10' != 1)
print('10' > 10)
# Out:
# False
# True
# False
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 5
#       3 print('10' == 1)
#       4 print('10' != 1)
# ----> 5 print('10' > 10)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# Demonstrating the sorted() function:
first_greek = ['omega', 'alpha', 'pi', 'gamma']
first_greek_2 = sorted(first_greek)
print(first_greek)
print(first_greek_2)
print()
# Demonstrating the sort() method:
second_greek = ['omega', 'alpha', 'pi', 'gamma']
print(second_greek)
second_greek.sort()
print(second_greek)
# Out:
# ['omega', 'alpha', 'pi', 'gamma']
# ['alpha', 'gamma', 'omega', 'pi']
#
# ['omega', 'alpha', 'pi', 'gamma']
# ['alpha', 'gamma', 'omega', 'pi']

# %%
itg = 13
flt = 1.3
si = str(itg)
sf = str(flt)
print(si + ' ' + sf)
# Out:
# 13 1.3

# %%
si = '13'
sf = '1.3'
itg = int(si)
flt = float(sf)
print(itg + flt)
# Out:
# 14.3

# %%
# IBAN Validator.
iban = input("Enter IBAN, please: ")
iban = iban.replace(' ','')
if not iban.isalnum():
    print("You have entered invalid characters.")
elif len(iban) < 15:
    print("IBAN entered is too short.")
elif len(iban) > 31:
    print("IBAN entered is too long.")
else:
    iban = (iban[4:] + iban[0:4]).upper()
    iban2 = ''
    for ch in iban:
        if ch.isdigit():
            iban2 += ch
        else:
            iban2 += str(10 + ord(ch) - ord('A'))
        iban = int(iban2)
    if iban % 97 == 1:
        print("IBAN entered is valid.")
    else:
        print("IBAN entered is invalid.")
# Out:
# IBAN entered is invalid.

# %%
# Caesar cipher.
text = input("Enter your message: ")
cipher = ''
for char in text:
    if not char.isalpha():
        continue
    char = char.upper()
    code = ord(char) + 1
    if code > ord('Z'):
        code = ord('A')
    cipher += chr(code)

print(cipher)
# Out:
# BTE

# %%
# Caesar cipher - decrypting a message.
cipher = input('Enter your cryptogram: ')
text = ''
for char in cipher:
    if not char.isalpha():
        continue
    char = char.upper()
    code = ord(char) - 1
    if code < ord('A'):
        code = ord('Z')
    text += chr(code)
    
print(text)
# Out:
# ASD
